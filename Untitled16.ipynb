# %% [markdown]
# # **Sentiment Analysis of Amazon Fine Food Reviews**
#
# **Aim :** To determine the sentiment of a given review. (Negative/ Neutral/ Positive)
#
# **ML Task :** Supervised Learning Multi-Class Text Classification
#
#
# **Performance metrics :** Accuracy, Confusion matrix
#
# **Representation Model used :** RoBERTa
#
# **Algorithm used :** Naive Bayes , Logistic Regression

# %% [markdown]
# ***TEAM 5***
#
# 1.  Naglakshmi G (*21ITB12*)
# 2.  Niveatha N   (*21ITB14*)
# 3.  Poornima K   (*21ITB15*)
# 4.  Yogita C M   (*21ITB18*)

# %% [markdown]
# import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud, STOPWORDS
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix

import string
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

from keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense , LSTM , Embedding
from keras.models import Sequential
from keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')

import pickle

# %% [markdown]
# # ***Data Preparation***

# %% [markdown]
# *Load data*

# %%
import pandas as pd

import csv
data = pd.read_csv("/content/Reviews.csv")
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
print(data.shape)
# Out:
# (2000, 10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk
ax = data['Score'].value_counts().sort_index() \
    .plot(kind='bar',color='purple',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# # ***Data cleaning***

# %% [markdown]
# *Handling missing values*

# %%
# Check null values
data.isna().sum().to_frame(name='# of missing values')
# Out:
#                         # of missing values
# Id                                        0
# ProductId                                 0
# UserId                                   13
# ProfileName                               0
# HelpfulnessNumerator                      0
# HelpfulnessDenominator                    0
# Score                                     0
# Time                                      0
# Summary                                  12
# Text                                      0

# %% [markdown]
# *Removing rows which are having null values*

# %%
total_rows =  data.shape[0]
data.dropna(how='any',inplace=True)
remaining_rows= data.shape[0]

removed_rows = total_rows-remaining_rows
print("No. of rows removed :", removed_rows)

print(f"\nPercentage of data removed:{np.round((removed_rows/total_rows)*100,2)}%")
print(f"Percentage of data remaining:{np.round((remaining_rows/total_rows)*100,2)}%")
# Out:
# No. of rows removed : 25
#
# Percentage of data removed:1.25%
# Percentage of data remaining:98.75%

# %% [markdown]
# *Removing duplicate rows*

# %%
a =  data.shape[0]
data.drop_duplicates(inplace=True, subset=['Score','Text'])
b = data.shape[0]

print("No. of rows removed :", a-b)

print(f"\nPercentage of data removed: {np.round(((a-b)/total_rows)*100,2)}%")
print(f"Percentage of data remaining: {np.round((b/total_rows)*100,2)}%")
# Out:
# No. of rows removed : 4
#
# Percentage of data removed: 0.2%
# Percentage of data remaining: 98.55%

# %% [markdown]
# *Removing outliers*

# %%
## `Score` > 3 : "Positive"
## `Score` == 3 : "Neutral"
## `Score` < 3 : "Negative"

def create_target(x):

    return "Positive" if x>3 else "Negative" if x<3 else "Neutral"

data.loc[:, 'target'] = data.Score.apply(create_target)

# %%
# Display the 'Score' and 'target' columns
print(data[['Score', 'target']].sample(10))
# Out:
#       Score    target
# 566       1  Negative
# 114       5  Positive
# 197       3   Neutral
# 1494      3   Neutral
# 881       4  Positive
# 543       1  Negative
# 1334      5  Positive
# 376       5  Positive
# 1748      5  Positive
# 1141      5  Positive

# %% [markdown]
# # ***Handling class Imbalance***

# %% [markdown]
# *Target distribution (Before)*

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
fig, ax = plt.subplots(figsize=(16, 6))

vc = data.target.value_counts()
vc.plot.barh(color="Purple",fontsize=14,ax=ax)
ax.set_title("Label vs Count", fontsize=15)
plt.show()

# %% [markdown]
# *Down sampling (remove some positive and negative reviews)*

# %%
positive_count = len(data[data.target=="Positive"])
negative_count = len(data[data.target=="Negative"])
neutral_count = len(data[data.target=="Neutral"])

print("Positive Count:", positive_count)
print("Negative Count:", negative_count)
print("Neutral Count:", neutral_count)
# Out:
# Positive Count: 1533
# Negative Count: 277
# Neutral Count: 161

# %%
fig, ax = plt.subplots(figsize=(16, 6))

vc = data.target.value_counts()
vc.plot.barh(color="pink",fontsize=14,ax=ax)
ax.set_title("Label vs Count", fontsize=15)
plt.show()

# %% [markdown]
# # ***Data Pre-processing***

# %% [markdown]
# *Stop words*

# %%
 import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
total_stopwords = set(stopwords.words('english'))

# subtract negative stop words like no, not, don't etc.. from total_stopwords
negative_stop_words = set(word for word in total_stopwords
                          if "n't" in word or 'no' in word)

final_stopwords = total_stopwords - negative_stop_words

#
final_stopwords.add("one")
print(final_stopwords)
# Out:
# {'having', 's', 'i', 'his', 'm', 'about', 'most', "should've", 'our', 'why', 'too', 't', 'all', 'those', 'these', 'weren', 'you', 'further', 'while', 'at', 'a', 'o', 'off', 'ourselves', 'once', 'there', 've', 'itself', 'by', 'aren', 'y', 'shan', 'again', 'how', "that'll", 'my', 'up', 'them', 'ours', 'being', 'should', 'just', 'hasn', 'with', 'ain', 'couldn', 'do', 'each', 'against', 'won', 'until', 'doesn', 'own', 'me', 'mightn', 'if', 'are', 'had', 'an', 'as', "you'll", 'one', 'that', 'both', 'or', 'such', 'where', 'we', 'from', 'other', 'wasn', 'after', 'between', 'am', 'myself', 'before', 'were', 'the', 'under', 'because', 'some', 'for', 'your', 'down', 'here', 'below', 'her', 'did', 'was', 'few', 'their', 'what', 'when', 'and', 'it', 'through', 're', 'does', 'been', 'd', 'is', 'hers', 'don', 'more', 'they', 'only', 'its', 'during', 'very', 'can', 'in', 'themselves', 'mustn', 'isn', 'ma', 'haven', "you've", 'yours', 'shouldn', 'which', 'herself', 'than', "it's", 'above', 'him', 'doing', 'into', 'hadn', 'whom', "you're", 'be', 'who', 'on', 'theirs', 'have', 'needn', "you'd", 'will', 'didn', 'himself', 'she', 'wouldn', 'out', 'yourselves', 'yourself', "she's", 'he', 'has', 'any', 'this', 'same', 'but', 'll', 'so', 'over', 'to', 'then', 'of'}

# %% [markdown]
# *Remove unwanted words from reviews*
# ### Ex. html tags, punctuation, stop words, etc..

# %%
#stemming object
stemmer = PorterStemmer()

# ---------------------------------------------
HTMLTAGS = re.compile('<.*?>')
table = str.maketrans(dict.fromkeys(string.punctuation))
remove_digits = str.maketrans('', '', string.digits)
MULTIPLE_WHITESPACE = re.compile(r"\s+")
# ---------------------------------------------

# %%
def preprocessor(review):
    # remove html tags
    review = HTMLTAGS.sub(r'', review)

    # remove puncutuation
    review = review.translate(table)

    # remove digits
    review = review.translate(remove_digits)

    # lower case all letters
    review = review.lower()

    # replace multiple white spaces with single space
    review = MULTIPLE_WHITESPACE.sub(" ", review).strip()

    # remove stop words
    review = [word for word in review.split()
              if word not in final_stopwords]

    # stemming
    review = ' '.join([stemmer.stem(word) for word in review])

    return review

# %%
print("Before preprocessing : ")
data.Text.iloc[6]
# Out:
# Before preprocessing :
# "This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, Fralinger's.  Would highly recommend this candy!  I served it at a beach-themed party and everyone loved it!"

# %%
data.Text = data.Text.apply(preprocessor)
print("After preprocessing : ")
data.Text.iloc[6]
# Out:
# After preprocessing :
# 'saltwat taffi great flavor soft chewi candi individu wrap well none candi stuck togeth happen expen version frale would highli recommend candi serv beachthem parti everyon love'

# %% [markdown]
# # ***Word clouds***

# %%
def generate_wcloud(text):
    stopwords = set(STOPWORDS)

    wordcloud = WordCloud(stopwords=stopwords, background_color='white')
    wordcloud.generate(text)

    plt.figure(figsize=(15,7))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation='bilinear')
    return plt.show()

# %% [markdown]
# *Word cloud for Positive reviews*

# %%
pos = data.loc[data.target=="Positive"].Text
text = " ".join(review for review in pos.astype(str))

generate_wcloud(text)

# %% [markdown]
# Word cloud for Negative reviews

# %%
pos = data.loc[data.target=="Negative"].Text
text = " ".join(review for review in pos.astype(str))

generate_wcloud(text)

# %% [markdown]
# *Word cloud for Neutral reviews*

# %%
pos = data.loc[data.target=="Neutral"].Text
text = " ".join(review for review in pos.astype(str))

generate_wcloud(text)

# %% [markdown]
# # ***Train Test Split***

# %% [markdown]
# Train set : 70% of data
#
# Test set : 30% of data

# %%
X = data.Text
y = data.target

X_train, X_test, y_train, y_test = train_test_split(

    X, y, test_size=0.20, random_state=1, stratify=y)

# %%
X_train.shape, X_test.shape
# Out:
# ((1576,), (395,))

# %% [markdown]
# # ***Vectorization***

# %% [markdown]
# *Bag of Words Vectorizer*

# %%
bow_vectorizer = CountVectorizer(max_features=10000)
bow_vectorizer.fit(X_train)

# transform
bow_X_train = bow_vectorizer.transform(X_train)
bow_X_test = bow_vectorizer.transform(X_test)

# %% [markdown]
# *TF-IDF Vectorizer*

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=10000)
tfidf_vectorizer.fit(X_train)

# transform
tfidf_X_train = tfidf_vectorizer.transform(X_train)
tfidf_X_test = tfidf_vectorizer.transform(X_test)

# %% [markdown]
# *Label Encoding*

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming you have y_train and y_test defined

# Initialize LabelEncoder
labelEncoder = LabelEncoder()

# Fit and transform y_train
y_train_encoded = labelEncoder.fit_transform(y_train)

# Transform y_test
y_test_encoded = labelEncoder.transform(y_test)

# Get the class labels
labels = labelEncoder.classes_

# Define a custom label mapping dictionary
label_mapping = {0: 'negative', 1: 'neutral', 2: 'positive'}

# Replace numerical values with corresponding labels
y_train_labels = [label_mapping[label] for label in y_train_encoded]
y_test_labels = [label_mapping[label] for label in y_test_encoded]

# Print the class labels
print(label_mapping.values())
# Out:
# dict_values(['negative', 'neutral', 'positive'])

# %%
labelEncoder = LabelEncoder()

y_train = labelEncoder.fit_transform(y_train)
y_test = labelEncoder.transform(y_test)

labels = labelEncoder.classes_.tolist()

# %% [markdown]
# *Basic NLTK*

# %%
example = data['Text'][50]  #arr[2][3]
print(example)
# Out:
# oatmeal not good mushi soft dont like quaker oat way go

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !python -m nltk.downloader averaged_perceptron_tagger
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# !python -m nltk.downloader maxent_ne_chunker
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['oatmeal',
#  'not',
#  'good',
#  'mushi',
#  'soft',
#  'dont',
#  'like',
#  'quaker',
#  'oat',
#  'way']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('oatmeal', 'IN'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('mushi', 'NN'),
#  ('soft', 'JJ'),
#  ('dont', 'NN'),
#  ('like', 'IN'),
#  ('quaker', 'NN'),
#  ('oat', 'NN'),
#  ('way', 'NN')]

# %%
# !python -m nltk.downloader words
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   oatmeal/IN
#   not/RB
#   good/JJ
#   mushi/NN
#   soft/JJ
#   dont/NN
#   like/IN
#   quaker/NN
#   oat/NN
#   way/NN
#   go/VBP)

# %%
# !python -m nltk.downloader vader_lexicon
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sia.polarity_scores('I am very happy')
# Out:
# {'neg': 0.0, 'neu': 0.334, 'pos': 0.666, 'compound': 0.6115}

# %%
sia.polarity_scores('This is the worst thing')
# Out:
# {'neg': 0.506, 'neu': 0.494, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.334, 'neu': 0.666, 'pos': 0.0, 'compound': -0.5448}

# %%
res = {}
for i, row in tqdm(data.iterrows(), total=len(data)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/1971 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(data, how='left')

# %%
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.573  0.427    0.9081  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.092  0.801  0.106    0.0762  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.136  0.650  0.214    0.6249  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  0.854  0.146    0.4404  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.455  0.545    0.9186  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text    target
# 0  bought sever vital can dog food product found ...  Positive
# 1  product arriv label jumbo salt peanutsth peanu...  Negative
# 2  confect around centuri light pillowi citru gel...  Positive
# 3  look secret ingredi robitussin believ found go...  Negative
# 4  great taffi great price wide assort yummi taff...  Positive

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots with 1 row and 3 columns
fig, axs = plt.subplots(1, 3, figsize=(12, 3))

# Plot bar plots for positive, neutral, and negative sentiments
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0], color='green')  # Positive sentiment in green
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1], color='gray')   # Neutral sentiment in gray
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2], color='red')    # Negative sentiment in red

# Set titles for each subplot
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # ***Model Training***

# %%
def train_and_eval(model, trainX, trainY, testX, testY):

    # training
    _ = model.fit(trainX, trainY)

    # predictions
    y_preds_train = model.predict(trainX)
    y_preds_test = model.predict(testX)

    # evaluation
    print()
    print(model)
    print(f"Train accuracy score : {accuracy_score(y_train, y_preds_train)}")
    print(f"Test accuracy score : {accuracy_score(y_test, y_preds_test)}")
    print('\n',40*'-')

# %% [markdown]
# *Logistic Regression with BoW*

# %%
# Hyperparameters
C = [0.001, 0.01, 0.1, 1, 10]

for c in C:
    # Define model
    log_model = LogisticRegression(C=c, max_iter=500, random_state=1)

    # Train and evaluate model
    train_and_eval(model=log_model,
                   trainX=bow_X_train,
                   trainY=y_train,
                   testX=bow_X_test,
                   testY=y_test)
# Out:
# LogisticRegression(C=0.001, max_iter=500, random_state=1)
# Train accuracy score : 0.7810913705583756
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------
#
# LogisticRegression(C=0.01, max_iter=500, random_state=1)
# Train accuracy score : 0.8191624365482234
# Test accuracy score : 0.7949367088607595
#
#  ----------------------------------------
#
# LogisticRegression(C=0.1, max_iter=500, random_state=1)
# Train accuracy score : 0.9346446700507615
# Test accuracy score : 0.8075949367088607
#
#  ----------------------------------------
#
# LogisticRegression(C=1, max_iter=500, random_state=1)
# Train accuracy score : 0.9993654822335025
# Test accuracy score : 0.7924050632911392
#
#  ----------------------------------------
#
# LogisticRegression(C=10, max_iter=500, random_state=1)
# Train accuracy score : 1.0
# Test accuracy score : 0.7848101265822784
#
#  ----------------------------------------

# %% [markdown]
# *Naive Bayes Classifier with BoW*

# %%
alphas = [0, 0.2, 0.6, 0.8, 1]

for a  in alphas:
    # Define model
    nb_model = MultinomialNB(alpha=a)

    # Train and evaluate model
    train_and_eval(model=nb_model,
                   trainX=bow_X_train,
                   trainY=y_train,
                   testX=bow_X_test,
                   testY=y_test)
# Out:
# MultinomialNB(alpha=0)
# Train accuracy score : 0.9879441624365483
# Test accuracy score : 0.7949367088607595
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.2)
# Train accuracy score : 0.9714467005076142
# Test accuracy score : 0.7924050632911392
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.6)
# Train accuracy score : 0.9486040609137056
# Test accuracy score : 0.8
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.8)
# Train accuracy score : 0.9289340101522843
# Test accuracy score : 0.7974683544303798
#
#  ----------------------------------------
#
# MultinomialNB(alpha=1)
# Train accuracy score : 0.9105329949238579
# Test accuracy score : 0.8075949367088607
#
#  ----------------------------------------

# %% [markdown]
# *Logistic Regression with Tf-Idf*

# %%
# Hyperparameters
C = [0.001, 0.01, 0.1, 1, 10]

for c in C:
    # Define model
    log_model = LogisticRegression(C=c, max_iter=500, random_state=1)

    # Train and evaluate model
    train_and_eval(model=log_model,
                   trainX=tfidf_X_train,
                   trainY=y_train,
                   testX=tfidf_X_test,
                   testY=y_test)
# Out:
# LogisticRegression(C=0.001, max_iter=500, random_state=1)
# Train accuracy score : 0.7779187817258884
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------
#
# LogisticRegression(C=0.01, max_iter=500, random_state=1)
# Train accuracy score : 0.7779187817258884
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------
#
# LogisticRegression(C=0.1, max_iter=500, random_state=1)
# Train accuracy score : 0.7779187817258884
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------
#
# LogisticRegression(C=1, max_iter=500, random_state=1)
# Train accuracy score : 0.8464467005076142
# Test accuracy score : 0.8025316455696202
#
#  ----------------------------------------
#
# LogisticRegression(C=10, max_iter=500, random_state=1)
# Train accuracy score : 1.0
# Test accuracy score : 0.8202531645569621
#
#  ----------------------------------------

# %% [markdown]
# *Naive Bayes classifier with Tf-Idf*

# %%
alphas = [0, 0.2, 0.6, 0.8, 1]

for a  in alphas:
    # Define model
    nb_model = MultinomialNB(alpha=a)

    # Train and evaluate model
    train_and_eval(model=nb_model,
                   trainX=tfidf_X_train,
                   trainY=y_train,
                   testX=tfidf_X_test,
                   testY=y_test)
# Out:
# MultinomialNB(alpha=0)
# Train accuracy score : 0.9854060913705583
# Test accuracy score : 0.7924050632911392
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.2)
# Train accuracy score : 0.858502538071066
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.6)
# Train accuracy score : 0.7810913705583756
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.8)
# Train accuracy score : 0.7791878172588832
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------
#
# MultinomialNB(alpha=1)
# Train accuracy score : 0.7779187817258884
# Test accuracy score : 0.7772151898734178
#
#  ----------------------------------------

# %% [markdown]
# # ***Roberta Pre-Trained Model***

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
# VADER results on example
print(example)
sia.polarity_scores(example)
# Out:
# oatmeal not good mushi soft dont like quaker oat way go
# {'neg': 0.334, 'neu': 0.666, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.97240824, 'roberta_neu': 0.025424156, 'roberta_pos': 0.002167554}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(data.iterrows(), total=len(data)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/1971 [00:00<?, ?it/s]
# Broke for id 540
# Broke for id 1321
# Broke for id 1498

# %%
results_data = pd.DataFrame(res).T

# Reset the index and rename the columns
results_data = results_data.reset_index().rename(columns={'index': 'Id'})

# Merge the results with the original data
results_data = results_data.merge(data, how='left')

# %% [markdown]
# ***Compare Score between Models***

# %%
sns.pairplot(data=results_data,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()

# %% [markdown]
# # ***Model Evaluation***

# %%
def plot_cm(y_true, y_pred):
    plt.figure(figsize=(6,6))

    cm = confusion_matrix(y_true, y_pred, normalize='true')

    sns.heatmap(
        cm, annot=True, cmap='Blues', cbar=False, fmt='.2f',
        xticklabels=labels, yticklabels=labels)

    return plt.show()

# %% [markdown]
# *Best model : Logistic Regression(C=1) with TfIdf data*

# %%
bmodel = LogisticRegression(C=1, max_iter=500, random_state=1)
bmodel.fit(tfidf_X_train, y_train)
# Out:
# LogisticRegression(C=1, max_iter=500, random_state=1)

# %%
# predictions
y_preds_train = bmodel.predict(tfidf_X_train)
y_preds_test = bmodel.predict(tfidf_X_test)

# %% [markdown]
# *Accuracy*

# %%
print(f"Train accuracy score : {accuracy_score(y_train, y_preds_train)}")
print(f"Test accuracy score : {accuracy_score(y_test, y_preds_test)}")
# Out:
# Train accuracy score : 0.8464467005076142
# Test accuracy score : 0.8025316455696202

# %% [markdown]
# *Confusion Matrix*

# %%
plot_cm(y_test, y_preds_test)

# %% [markdown]
# # ***Deployment***

# %%
with open("transformer.pkl", "wb") as f:
    pickle.dump(tfidf_vectorizer, f)

with open("model.pkl", "wb") as f:
    pickle.dump(bmodel, f)

# %% [markdown]
# *Prediction on single review*

# %%
labels = ['Negative','Neutral','Positive']

def get_sentiment(review):
    # Preprocessing
    x = preprocessor(review)

    # Vectorization
    x = tfidf_vectorizer.transform([x])

    # Prediction
    y = int(bmodel.predict(x.reshape(1,-1))[0])

    return labels[y]

# %%
review = "This chips packet is very tasty. I highly recommend this!"
print(f"This is a {get_sentiment(review)} review!")
# Out:
# This is a Positive review!

# %%
# positve review
review = "This product is a much seem of money!!"
print(f"This is a {get_sentiment(review)} review!")
# Out:
# This is a Negative review!
